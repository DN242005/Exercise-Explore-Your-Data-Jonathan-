# %% [markdown]
# # Iowa Housing: primeros pasos con pandas
#
# Este notebook reproduce los pasos del ejercicio: cargar los datos y revisarlos.

# %%
import pandas as pd

# Coloca train.csv en esta misma carpeta
iowa_file_path = 'train.csv'
home_data = pd.read_csv(iowa_file_path)

home_data.head()

# %% [markdown]
# ## Paso 2: revisar los datos

# %%
# Estadísticas resumen
home_data.describe()

# %%
# Respuestas del ejercicio
avg_lot_size = round(home_data.LotArea.mean())
newest_home_age = 2026 - home_data.YearBuilt.max()

print(f'Tamaño medio del lote: {avg_lot_size}')
print(f'Antigüedad de la vivienda más nueva: {newest_home_age} años')
